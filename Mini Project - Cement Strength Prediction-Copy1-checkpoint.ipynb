# %% [markdown]
# ## About
#
# #### Concrete is the most important material in civil engineering.
# #### This project is helping to predict the strength of cement for a civil engineer
# #### Benifits of this model Quality Assurance,Optimized Mix Design,Time Savings,Resource Efficiency,Enhanced Safety,Long-Term Durability

# %% [markdown]
# ## Dataset
# #### Cement (component 1) -- quantitative -- kg in a m3 mixture -- Input Variable
# ####  Blast Furnace Slag (component 2) -- quantitative -- kg in a m3 mixture -- Input Variable
# ####  Fly Ash (component 3) -- quantitative -- kg in a m3 mixture -- Input Variable
# ####  Water (component 4) -- quantitative -- kg in a m3 mixture -- Input Variable
# ####  Superplasticizer (component 5) -- quantitative -- kg in a m3 mixture -- Input Variable ---additives used for making high-strength concrete or to place self-compacting concrete
# ####  Coarse Aggregate (component 6) -- quantitative -- kg in a m3 mixture -- Input Variable
# ####  Fine Aggregate (component 7) -- quantitative -- kg in a m3 mixture -- Input Variable
# ####  Age -- quantitative -- Day (1~365) -- Input Variable
# ####  Concrete compressive strength -- quantitative -- MPa -- Output Variable
# ## Acknowledgements
# ### Source:
# ####    Original Owner and Donor
# ####    Prof. I-Cheng Yeh
# ####    Department of Information Management
# ####    Chung-Hua University,
# ####    Hsin Chu, Taiwan 30067, R.O.C.
# ####    e-mail:icyeh '@' chu.edu.tw
# ####    TEL:886-3-5186511
# ####
# ####    Date Donated: August 3, 2007
# ####
# ####    From: https://archive.ics.uci.edu/ml/datasets/Concrete+Compressive+Strength

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from tkinter import *
import tkinter 
from flask import Flask,request,jsonify
import pymongo
from sklearn.manifold import TSNE
from tkinter import PhotoImage
from PIL import Image, ImageTk
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Concrete_Data_Yeh.csv")

# %%
df
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# ...

# %%
df.dtypes
# Out:
# cement              float64
# slag                float64
# flyash              float64
# water               float64
# superplasticizer    float64
# coarseaggregate     float64
# fineaggregate       float64
# age                   int64
# csMPa               float64
# dtype: object

# %% [markdown]
# ### Visualization

# %%
df.head(3)
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27

# %%
sns.scatterplot(df["cement"], df["csMPa"])
# Out:
# <Axes: xlabel='cement', ylabel='csMPa'>

# %%
sns.scatterplot(df["slag"], df["csMPa"])
# Out:
# <Axes: xlabel='slag', ylabel='csMPa'>

# %%
sns.scatterplot(df["flyash"], df["csMPa"])
# Out:
# <Axes: xlabel='flyash', ylabel='csMPa'>

# %%
sns.scatterplot(df["water"], df["csMPa"])
# Out:
# <Axes: xlabel='water', ylabel='csMPa'>

# %%
sns.scatterplot(df["age"], df["csMPa"])
# Out:
# <Axes: xlabel='age', ylabel='csMPa'>

# %%
plt.figure(figsize=(8,8))
    #ax = plot.subplot(5,3,plotnumber)
sns.heatmap(df[["cement","slag","flyash","water","superplasticizer","coarseaggregate","fineaggregate","age","csMPa"]].corr().abs(), vmin = -0.5,vmax = 1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### TSNE

# %%
xtsne=df[["cement","slag","flyash","water","superplasticizer","coarseaggregate","fineaggregate","age"]]

# %%
ytsne=df[["csMPa"]]

# %%
tsne=TSNE(n_components=2,random_state=0,n_iter=1000).fit_transform(xtsne)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=tsne[:,0],y=tsne[:,1],hue=df['csMPa'])
plt.show()

# %%
x=df[["cement","slag","flyash","water","superplasticizer","coarseaggregate","fineaggregate","age"]]

# %%
x
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age
# 0             676.0   28
# 1             676.0   28
# 2             594.0  270
# ...

# %%
y=df[["csMPa"]]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler

sc_x = StandardScaler()
x = sc_x.fit_transform(x)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.3,random_state=1000)

# %%
rf_regressor=RandomForestRegressor(n_estimators=1000,random_state=1000)
svc_regressor=SVR()
dt_regressor=DecisionTreeRegressor()

# %%
svc_regressor.fit(xtrain, ytrain)
dt_regressor.fit(xtrain, ytrain)
rf_regressor.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=1000)

# %%
svc_reg_ypred = svc_regressor.predict(xtest)
dt_reg_ypred = dt_regressor.predict(xtest)
rf_reg_ypred = rf_regressor.predict(xtest)

# %%
plt.plot(xtrain,ytrain,"+",color='green')
plt.plot(xtest,rf_reg_ypred,'*',color='red')
plt.title("random forest prediction \n green -> training data\n red->testing data")
# Out:
# Text(0.5, 1.0, 'random forest prediction \n green -> training data\n red->testing data')

# %%
plt.plot(xtrain,ytrain,"+",color='green')
plt.plot(xtest,dt_reg_ypred,'*',color='red')
plt.title("Decision Tree prediction \n green -> training data\n red->testing data")
# Out:
# Text(0.5, 1.0, 'Decision Tree prediction \n green -> training data\n red->testing data')

# %%
plt.plot(xtrain,ytrain,"+",color='green')
plt.plot(xtest,svc_reg_ypred,'*',color='red')
plt.title("Support Vector Machine \n green -> training data\n red->testing data")
# Out:
# Text(0.5, 1.0, 'Support Vector Machine \n green -> training data\n red->testing data')

# %%
svc_reg_err = mean_squared_error(ytest, svc_reg_ypred)
dt_reg_err = mean_squared_error(ytest, dt_reg_ypred)
rf_reg_err = mean_squared_error(ytest, rf_reg_ypred)

# %%
print ("Decision Tree error                : ", round(dt_reg_err, 2))
print ("Random Forest error                : ", round(rf_reg_err, 2)) 
print ("Support Vector Machine error       : ", round(svc_reg_err, 2))
# Out:
# Decision Tree error                :  63.04
# Random Forest error                :  29.47
# Support Vector Machine error       :  98.2

# %% [markdown]
# ## Using Random forest regressor and creating a Machine learning API , along with user interface to intaract , and mongodb database , to store users data for future model training

# %%
from flask import Flask
client=pymongo.MongoClient("mongodb+srv://satwikit21051:Satwik2021@cluster0.bkhztv9.mongodb.net/?retryWrites=true&w=majority")
db=client.test
db=client['prediction']
col=db["table"]
app = Flask(__name__)

@app.route('/satwik', methods=['GET'])
def satwik():
        def predict():
                    A=float(e1.get())
                    B=float(e2.get())
                    C=float(e3.get())
                    D=float(e4.get())
                    E=float(e5.get())
                    F=float(e6.get())
                    G=float(e7.get())
                    H=float(e7.get())
                    dict = {
                         'cement':A,
                         'slag':B,
                         'flyash':C,
                         'water':D,
                         'superplasticizer':E,
                         'coarseaggregate':F,
                        'fineaggregate':G,
                         'age':H
                     }

                    col.insert_one(dict)
                    latest = col.find().sort([('_id', pymongo.DESCENDING)]).limit(1)

                    for doc in latest:
                         data=doc
                    
                    input=pd.DataFrame(data,index=[0])
                    del input["_id"]
                    prediction = float(rf_regressor.predict(input))  
                    display.insert(0,float(prediction))
             
        def clear():
                    e1.delete(0, END)
                    e2.delete(0, END)
                    e3.delete(0, END)
                    e4.delete(0, END)
                    e5.delete(0, END)
                    e6.delete(0, END)
                    e7.delete(0, END)
                    e8.delete(0, END)
                    display.delete(0, END)
                    col.delete_many({})
        root = Tk()
        root.geometry('400x200+100+200')
        original_image = Image.open("Bridge.png") 
        width, height = 400, 300  
        resized_image = original_image.resize((width, height), Image.ANTIALIAS)
        photo = ImageTk.PhotoImage(resized_image)
        background_label = Label(root, image=photo)
        background_label.place(x=800, y=180, width=width, height=height)

        l1 = Label(root, text="Cement Amount (kg/m3 mixture)",  font="Arial 10 bold")
        sat = Label(root, text="By Satwik Tiwari",  font="Arial 9 bold")
        l2 = Label(root, text="Blast furnace slag Amount (kg/m3 mixture)",font="Arial 10 bold")
        l3 = Label(root, text="Fly ash (kg/m3 mixture)",  font="Arial 10 bold")
        l4 = Label(root, text="Water Amount (kg/m3 mixture)", font="Arial 10 bold")
        l5 = Label(root, text="Superplasticizer (kg/m3 mixture)", font="Arial 10 bold")
        l6 = Label(root, text="Coarse aggregate (kg/m3 mixture)", font="Arial 10 bold")
        l7 = Label(root, text="Fine aggregate (kg/m3 mixture)", font="Arial 10 bold")
        l8 = Label(root, text="Age of cement (1~365 days)", font="Arial 10 bold")
        l1.pack()
        l = Label(root, text="Prediction Of Cement Strength Using Machine Learning",bg="gray" , font="Arial 30 bold")
        lb1=Label(root, text="1.Blast Furnace Slag->    a nonmetallic coproduct produced in the process ")
        lb2=Label(root, text="2.Fly ash->     a green construction material used to produce durable concrete")
        lb3=Label(root, text="3.Superplasticizer->     additives used for making high-strength concrete or to place self-compacting concrete.->additives used for making high-strength concrete or to place self-compacting concrete.")
        lb4=Label(root, text="4.Coarse aggregate->     irregular and granular materials such as sand, gravel, or crushed stone, and are used for making concrete")
        lb5=Label(root, text="5.Fine aggregate->      any natural sand particles won from the land through the mining process")
        lb1.place(x=150,y=520)
        lb2.place(x=150,y=540)
        lb3.place(x=150,y=560)
        lb4.place(x=150,y=580)
        lb5.place(x=150,y=600)
        sat.place(x=0,y=0)
        b1=Button(root,text="predict(in MPa)",font="Arial 12 bold",bg="green",command=predict)
        b2=Button(root,text="clear",font="Arial 12 bold",bg="red",command=clear)
        l1.place(x=150,y=215)
        l2.place(x=150,y=235)
        l3.place(x=150,y=255)
        l4.place(x=150,y=275)
        l5.place(x=150,y=295)
        l6.place(x=150,y=315)
        l7.place(x=150,y=335)
        l8.place(x=150,y=355)
        b1.place(x=150,y=450)
        l.place(x=130,y=60)

        e1=Entry(root,bg="pink")
        e2=Entry(root,bg="pink")
        e3=Entry(root,bg="pink")
        e4=Entry(root,bg="pink")
        e5=Entry(root,bg="pink")
        e6=Entry(root,bg="pink")
        e7=Entry(root,bg="pink")
        e8=Entry(root,bg="pink")
        display=Entry(root)
        e1.place(x=600,y=215)
        e2.place(x=600,y=236)
        e3.place(x=600,y=257)
        e4.place(x=600,y=278)
        e5.place(x=600,y=299)
        e6.place(x=600,y=320)
        e7.place(x=600,y=341)
        e8.place(x=600,y=362)
        b2.place(x=740,y=450)
        display.place(x=600,y=450)
        root.mainloop()
        return "hello...."
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Sep/2023 21:52:17] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Sep/2023 21:52:17] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Sep/2023 21:53:40] "GET /satwik HTTP/1.1" 200 -
